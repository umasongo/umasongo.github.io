# %%
import pandas as pd
df = pd.read_csv('data-excel.csv')
df.head()
# Out:
#           District  Reg. Voters AMURIAT OBOI PATRICK KABULETA KIIZA JOSEPH  \
# 0        001 APAC         88834          1483\n2.84%            277\n0.53%
# 1        002 ARUA         65738           491\n1.45%            180\n0.53%
# 2  003 BUNDIBUGYO        113472           227\n0.32%            119\n0.17%
# 3    004 BUSHENYI        140415          2029\n2.39%            295\n0.35%
# 4        005 GULU         45342          1165\n5.87%            255\n1.29%
#
#   KALEMBE NANCY LINDA KATUMBA JOHN KYAGULANYI SSENTAMU ROBERT   MAO NORBERT  \
# 0          263\n0.50%   246\n0.47%              16485\n31.55%    310\n0.59%
# 1          207\n0.61%   111\n0.33%               7966\n23.57%    240\n0.71%
# 2          153\n0.21%   148\n0.21%              18076\n25.18%     92\n0.13%
# 3          337\n0.40%   866\n1.02%              10937\n12.91%    138\n0.16%
# 4          171\n0.86%   119\n0.60%               3023\n15.24%  4011\n20.22%
#
# ...

# %%
df = df[['District', 'Reg. Voters', 'Total Votes', 'Received Station']]

# %%
df.head()
# Out:
#           District  Reg. Voters    Total Votes Received Station
# 0        001 APAC         88834  55413\n62.38%        179/\n179
# 1        002 ARUA         65738  36067\n54.86%        111/\n111
# 2  003 BUNDIBUGYO        113472  73918\n65.14%        297/\n298
# 3    004 BUSHENYI        140415  87415\n62.25%        258/\n258
# 4        005 GULU         45342  21894\n48.29%          92/\n92
